# %%
import psycopg2
import pandas as pd

# %%
def create_database():
    # connect to default database
    # conn = psycopg.2connect("host=127.0.0.1 dbname=studentdb user=student password=student")
    conn = psycopg2.connect("host=127.0.0.1 dbname=postgres user=postgres password=9310@Zkapffpdhs")
    conn.set_session(autocommit=True)
    cur=conn.cursor()
    
    # create sparkify database with UTF8 encoding
    cur.execute("DROP DATABASE IF EXISTS accounts")
    cur.execute("CREATE DATABASE accounts")
    
    # close connection to default database
    conn.close()
    
    # connect to sparkify database
    conn = psycopg2.connect("host=127.0.0.1 dbname=accounts user=postgres password=9310@Zkapffpdhs")
    cur = conn.cursor()
    
    return cur, conn

# %%
def drop_tables(cur, conn):
    for query in drop_table_queries:
        cur.execute(query)
        conn.commit()

# %%
def create_tables(cur, conn):
    for query in create_table_queries:
        cur.execute(query)
        conn.commit()

# %%
AccountsCountry = pd.read_csv("Datasets/Wealth-AccountsCountry.csv")

# %%
AccountsCountry.head()
# Out:
#   Country Code Short Name Table Name                  Long Name 2-alpha code  \
# 0          ALB    Albania    Albania        Republic of Albania           AL
# 1          ARG  Argentina  Argentina         Argentine Republic           AR
# 2          ARM    Armenia    Armenia        Republic of Armenia           AM
# 3          AUS  Australia  Australia  Commonwealth of Australia           AU
# 4          AUT    Austria    Austria        Republic of Austria           AT
#
#        Currency Unit                                      Special Notes  \
# 0       Albanian lek                                                NaN
# 1     Argentine peso                                                NaN
# 2      Armenian dram                                                NaN
# 3  Australian dollar  Fiscal year end: June 30; reporting period for...
# 4               Euro  A simple multiplier is used to convert the nat...
#
#                       Region         Income Group WB-2 code  ...  \
# ...

# %%
AccountsCountry_clean = AccountsCountry[['Country Code', 'Short Name', 'Table Name', 'Long Name','Currency Unit']]

# %%
AccountsCountry_clean.head()
# Out:
#   Country Code Short Name Table Name                  Long Name  \
# 0          ALB    Albania    Albania        Republic of Albania
# 1          ARG  Argentina  Argentina         Argentine Republic
# 2          ARM    Armenia    Armenia        Republic of Armenia
# 3          AUS  Australia  Australia  Commonwealth of Australia
# 4          AUT    Austria    Austria        Republic of Austria
#
#        Currency Unit
# 0       Albanian lek
# 1     Argentine peso
# 2      Armenian dram
# 3  Australian dollar
# 4               Euro

# %%
AccountsData = pd.read_csv("Datasets/Wealth-AccountData.csv")

# %%
AccountsData.head()
# Out:
#   Country Name Country Code  \
# 0      Albania          ALB
# 1      Albania          ALB
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                       Indicator Name  Indicator Code  \
# 0                  Human capital (constant 2018 US$)       NW.HCA.TO
# 1       Human capital per capita (constant 2018 US$)       NW.HCA.PC
# 2  Human capital per capita, employed female (con...  NW.HCA.FEMP.PC
# 3  Human capital per capita, employed male (const...  NW.HCA.MEMP.PC
# 4  Human capital per capita, female (constant 201...  NW.HCA.FEMA.PC
#
#        1995      1996      1997      1998      1999      2000  ...  \
# 0  4.49E+10  4.34E+10  3.71E+10  3.88E+10  4.22E+10  4.36E+10  ...
# 1  14072.79  13708.99   11794.1  12399.48  13573.26  14118.13  ...
# 2  3468.858  3355.549  2868.997  3013.391  3259.893  3424.007  ...
# 3  6507.931  6353.737  5466.692  5901.072   6492.73  6872.019  ...
# ...

# %%
AccountsData.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017', '2018'],
#       dtype='object')

# %%
# AccountsData = AccountsData.drop(['2017'], axis=1)
# axis=1 means it's a column
# axis=0 means it's a row
AccountsData_clean = AccountsData[['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code', '1995', '2000', '2005', '2010', '2014']]

# %%
AccountsData_clean.head()
# Out:
#   Country Name Country Code  \
# 0      Albania          ALB
# 1      Albania          ALB
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                       Indicator Name  Indicator Code  \
# 0                  Human capital (constant 2018 US$)       NW.HCA.TO
# 1       Human capital per capita (constant 2018 US$)       NW.HCA.PC
# 2  Human capital per capita, employed female (con...  NW.HCA.FEMP.PC
# 3  Human capital per capita, employed male (const...  NW.HCA.MEMP.PC
# 4  Human capital per capita, female (constant 201...  NW.HCA.FEMA.PC
#
#        1995      2000          2005          2010          2014
# 0  4.49E+10  4.36E+10  5.440000e+10  6.810000e+10  7.250000e+10
# 1  14072.79  14118.13  1.807230e+04  2.336286e+04  2.509002e+04
# 2  3468.858  3424.007  2.222115e+03  2.889150e+03  2.957420e+03
# 3  6507.931  6872.019  1.168935e+04  1.578992e+04  1.699138e+04
# ...

# %%
AccountsSeries = pd.read_csv("Datasets/Wealth-AccountSeries.csv")

# %%
AccountsSeries.columns
# Out:
# Index(['Series Code', 'Topic', 'Indicator Name', 'Short definition', 'Source',
#        'Topic.1', 'Unit of measure', 'Periodicity', 'Reference period',
#        'Statistical concept and methodology', 'Previous Indicator Code',
#        'Previous Indicator Name', 'Unnamed: 12', 'Short definition.1'],
#       dtype='object')

# %%
AccountsSeries = AccountsSeries[['Series Code','Topic', 'Indicator Name', 'Short definition']]

# %%
AccountsSeries.head()
# Out:
#       Series Code                                              Topic  \
# 0       NW.HCA.TO                  Human capital (constant 2018 US$)
# 1       NW.HCA.PC       Human capital per capita (constant 2018 US$)
# 2  NW.HCA.FEMP.PC  Human capital per capita, employed female (con...
# 3  NW.HCA.MEMP.PC  Human capital per capita, employed male (const...
# 4  NW.HCA.FEMA.PC  Human capital per capita, female (constant 201...
#
#                                       Indicator Name  Short definition
# 0  Human capital is computed as the present value...               NaN
# 1  Human capital is computed as the present value...               NaN
# 2  Human capital is computed as the present value...               NaN
# 3  Human capital is computed as the present value...               NaN
# 4  Human capital is computed as the present value...               NaN

# %%
cur, conn = create_database()

# %%
songplay_table_create = ("""CREATE TABLE IF NOT EXISTS AccountsCountry(
country_code VARCHAR,
short_name VARCHAR,
table_name VARCHAR,
long_name VARCHAR,
currency_unit VARCHAR
)""")

# %%
cur.execute(songplay_table_create)
conn.commit()

# %%
accounts_data_table_create = ("""CREATE TABLE IF NOT EXISTS accountsdata(
country_name VARCHAR,
country_code VARCHAR,
indicator_name VARCHAR,
indicator_code VARCHAR,
year_1995 varchar,
year_2000 varchar,
year_2005 varchar,
year_2010 varchar,
year_2014 varchar
)""")
cur.execute(accounts_data_table_create)
conn.commit()

# %%
accountsseries_data_table_create = ("""CREATE TABLE IF NOT EXISTS accountsseries(
series_code VARCHAR,
topic VARCHAR,
indicator_name VARCHAR,
short_definition VARCHAR
)""")
cur.execute(accountsseries_data_table_create)
conn.commit()

# %%
accounts_country_table_insert = ("""INSERT INTO accountscountry(
country_code,
short_name,
table_name,
long_name,
currency_unit)
VALUES (%s, %s, %s, %s, %s)
""")

# %%
for i, row in AccountsCountry_clean.iterrows():
    cur.execute(accounts_country_table_insert, list(row))
    # there is an error when primary key is used for country_code
    # however, when i remove primary key, then the error disappears
    # the error was about UniqueViolation

# %%
conn.commit()

# %%
accounts_data_table_insert = ("""INSERT INTO accountsdata(
country_name,
country_code,
indicator_name,
indicator_code,
year_1995,
year_2000,
year_2005,
year_2010,
year_2014)
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)
""")

# %%
for i, row in AccountsData_clean.iterrows():
        cur.execute(accounts_data_table_insert, list(row))

# %%
accountseries_data_table_insert = ("""INSERT INTO accountsseries(
series_code,
topic,
indicator_name,
short_definition)
VALUES (%s, %s, %s, %s)
""")

# %%
for i, row in AccountsSeries.iterrows():
    cur.execute(accountseries_data_table_insert, list(row))

# %%
conn.commit()
